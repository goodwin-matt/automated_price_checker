# %%
import requests
from bs4 import BeautifulSoup

# %%
HEADERS = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})

# %%
page = requests.get("https://www.amazon.com/Carhartt-Mens-Acrylic-Knit-Brown/dp/B003E7GUZU/ref=sr_1_2?crid=32RQ212UM3FQC&dchild=1&keywords=carhartt%2Bbeanie&qid=1609025320&sprefix=career%2Caps%2C250&sr=8-2&th=1&psc=1", headers=HEADERS)

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
soup.find(id='title').get_text().strip()
# Out:
# "Carhartt Men's Acrylic Knit Hat A205"

# %%
soup.find(id='priceblock_ourprice').get_text()
# Out:
# '$16.99'

# %%
page = requests.get("https://www.walmart.com/ip/Carhartt-Cuffed-Beanie-Acrylic-Watch-Hat-2-0/640541832", headers=HEADERS)

# %%
soup_wal = BeautifulSoup(page.content)

# %%
soup_wal.find(class_='prod-PriceSection').get_text()
# Out:
# '$24.99$24.99$24.99$24.99'

# %%
soup_wal
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# ...

# %% [markdown]
# #### Home depot

# %%
from selenium import webdriver

# %%
options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
options.add_argument('--headless')
driver = webdriver.Chrome("/Users/goodwinm/OurStuff/Matt/DS/DS_Projects/chromedriver", chrome_options=options)
# Out:
# /Users/goodwinm/OurStuff/Matt/DS/ds_373/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: use options instead of chrome_options
#   """

# %%
driver.get("https://www.homedepot.com/p/USG-Sheetrock-Brand-1-2-in-x-4-ft-x-8-ft-Ultralight-Gypsum-Board-14113411708/202530243")

# %%
test = driver.find_elements_by_class_name("price-format__main-price")

# %%
test[2].text
# Out:
# '$2567'

# %%
price = driver.find_elements_by_xpath("//span[@class='price-format__large-symbols']/following-sibling::span")

# %%
price
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4a04e9df4e27f22435d5739be184d34d", element="ad7e1fc0-ba7e-4165-9c83-7729a4ee3222")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4a04e9df4e27f22435d5739be184d34d", element="3b0c742d-ec62-498e-9259-14ee006be82d")>]

# %%
price[0].text + "." + price[1].text
# Out:
# '12.33'

# %%
price
# Out:
# []
